# %% [markdown]
# # Lecture 1
#
# ---
# ### Exercise: Selection Sort
# Write the function ```SelectionSort(coll)``` that returns a sorted list with the elements in *coll*.
# You have to implements Selection Sort algorithm.

# %%
## Your implementation here!!!

def SelectionSort(A):
    for i in range(len(A)):
        min_pos = i
        for j in range(i+1, len(A)):
            if A[j] < A[min_pos]:
                min_pos = j
        A[i], A[min_pos] = A[min_pos], A[i]
    return A

# %% [markdown]
# ----
# ### Exercise: Insertion Sort
# Write the function ```InsertionSort(coll)``` that returns a sorted list with the elements in *coll*.
# You have to implements Insertion Sort algorithm.

# %%
## Your implementation here!!!

def InsertionSort(A):
    
    for actual_pos in range(1, len(A)):
        key = A[actual_pos]
        prec_pos = actual_pos-1
        
        while prec_pos >= 0 and key < A[prec_pos]:
            A[prec_pos+1] = A[prec_pos]
            prec_pos -= 1
        A[prec_pos+1] = key
    return A

# %% [markdown]
# ----
# ### Exercise: Strange orderings
# Given a list, write and test comparators to obtain the following orderings:
# - Even number precede odd ones. Even numbers are sorted in non-decreasing  order while odd ones are sorted in non-increasing order.
# - Strings are sorted in non-increasing order based on their lengths. Strings having the same length are sorted in non-increasing lexicographic order.

# %%
## Your implementation here!!!

import functools

#1 even number preceed odd ones
#1----------
def IsItEven(num):
    return num %2 == 0 

def my_cmp_numbers(a, b):
    if b %2 == 0: return 1
    return -1

# print(sorted(my_list, key=functools.cmp_to_key(my_cmp_numbers))) # dont know why u left this here
#1----------

#2strings are sorted
#2----------
def my_cmp_strings(a, b):
    if len(a) < len(b): 
        return 1
    if len(a) == len(b):
        if str(a) < str(b):
            return 1
    return -1
    
# print(sorted(my_list2, key=functools.cmp_to_key(my_cmp_strings))) # dont know why u left this here
#2----------

# %% [markdown]
# -----
# ### Exercise: Insertion Sort with a comparator
# Write the function ```InsertionSort(coll, cmp)``` that returns a sorted list with the elements in *coll* using
# ```cmp```as a comparator.

# %%
## Your implementation here!!!

def cmp(a,b):
    if a < b:
        return -1
    if a > b:
        return 1
    if a == b:
        return 0

def InsertionSortComp(coll, cmp):
    
    for actual_pos in range(1, len(coll)):
        key = coll[actual_pos]
        prec_pos = actual_pos-1
        
        while prec_pos <= 0 and cmp(key, coll[prec_pos]) < 0 : # the precpos has to be >= 0 to be effective 
            coll[prec_pos+1] = coll[prec_pos]
            prec_pos -= 1
        coll[prec_pos+1] = coll[prec_pos]
    return coll

# %% [markdown]
# -----
#
# ### Exercise: Intersection of two lists
# Write a function ```intersection_slow(l1, l2)``` which returns the intersection of the two lists l1 and l2.
#
# Use the trivial algorithms that runs in $\Theta(|l1|\times|l2|)$.

# %%
## Your implementation here!!!

def intersection_slow(l1,l2):
    l3 = []
    for i in range(len(l1)):
        for j in range(len(l2)):
            if l1[i] == l2[j]:
                if l2[j] not in l3:
                    l3.append(l1[i])
                else:
                    break
    return l3

# %% [markdown]
# ----
# ### Exercise: Faster intersection of two lists
# Write a function ```intersection(l1, l2)``` which returns the intersection of the two lists l1 and l2.
#
# Assume that both l1 and l2 are sorted!

# %%
## Your implementation here!!!

def intersection_fast(l1,l2): # just to be sure that the lists were sorted i sort them inside the function but only for test purposes 
    l1 = sorted(l1)           # in a real case scenario i would assume that the lists are already sorted, because like this we adding O(nlogn) to the complexity by sorting
    l2 = sorted(l2)
    l3 = list()
    
    i = 0
    j = 0
    
    while i < len(l1) and j < len(l2): # if they are sorted we can just iterate through both lists and check if the elements are equal
        if l1[i] == l2[j]:
            l3.append(l1[i])
            i+= 1
            j+=1
            
        elif l1[i] < l2[j]: #if the elements are not the same check which list has the smaller element untile they are equal then check for the condition
            i+=1
            
        else: 
            j+=1
        
    return l3

# %% [markdown]
# ----
# ### Exercise: You own search engine
# You are given a collection of texts and you want to build your own search engine, people at Google are already very scared!
#
# Modern search engines are based on a data structure called *Inverted Index*.
#
# Each document of the collection is assigned an identifier, starting from 0.
# An inverted index stores a list, called *inverted list*, for each term of the collection.
# The list for a term *t* contains the identifiers of all the documents containing term *t*. The list is sorted.
#
# For example,
#
# ````
# C = ["dog cat elephant monkey",  "dog lion tiger", "fish dog dog cat cow"]
#
# ````
#
# The list of term *cat* is [0,2], the list of *elephant* is [0].
#
# Given two terms, an AND query reports all the documents containing both terms. For example,
# *query("cat", "dog"), the result is [0, 2].
#
# You goal is to implement a simple search engine. Do the following.
#
# - Given the collection, build a dictionary that maps each term to its inverted list. Observe that
# each document occurs at most once in each list.
# - Implement a function *query* which answers an AND query.

# %%
## Your implementation here!!!

def build_index(C):
    index = {}

    for doc_id, doc in enumerate(C): # just takes the documents id and the docs and returns a number of the doc and the doc itself
        terms = doc.split() #splits the doc into terms 
        for term in terms:
            if term in index:
                index[term].append(doc_id) # then just appends the doc id to the term if it's in the index or creates a new space for the term and appends the doc id
            else:
                index[term] = [doc_id]
                
    return index

def query(index, t1, t2): # just takes the index and the two terms and returns the intersection of the two terms to find in which documents id there are located both terms 
    l1 = index[t1]
    l2 = index[t2]
    return intersection_fast(l1,l2)

# %% [markdown]
# ----
# # Lecture 2
# ---
# ### Exercise: Binary Vector
# You are given a binary vector, i.e., each element is either 0 or 1. Implements an easy variant of partition to sort the vector.

# %%
## Your implementation goes here

def binary_sort(A):
    left = 0
    right = len(A) - 1

    while left < right:
        while A[left] == 0 and left < right: # iterates on the left part of the array until it finds a 1, since the left index is the first while it increases the left one untile it's equal to the right one and then returns the array
            left += 1 
        while A[right] == 1 and left < right: # iterates on the right part of the array until it finds a 0  
            right -= 1 

        if left < right: # if the left index is smaller than the right index, it means that we have found a 0 on the left and a 1 on the right, so we swap them and we continue iterating untile the indexes are equal
            A[left], A[right] = A[right], A[left] 
            left += 1
            right -= 1

    return A

# %% [markdown]
# ---
# ### Exercise: QuickSort
# Below an implementation of QuickSort.
#
# In this exercise you have to:
# - Write detailed comments to describe crucial parts of the code below (to prove you have understand it)
# - Implement a random selection of the pivot element

# %%
## Your implementation here!!!

def partition(A, low, high):
    
    pivot = random.randint(low, high) ## add here random selection of the pivot
    A[pivot], A[high] = A[high], A[pivot] ## swapping the randomly selected pivot to the last position of the array
    
    pivot = "A"[high] ## setting back the pivot to the last position since we already swapped the chosen one          #u forgot to put the A in front but it has the parentesis so maybe it's just a typo
    i = low -1  # setting index 1 position outside the array
    
    for j in range(low, high): # traversing the partition(s) with a for loop
        if A[j] <= pivot: # executing condition "<=" (traversing index against pivot)
            i = i+1 # if the condition holds, i moves forward by 1 every time, to track the index position
                    # of the < than pivot part of the array (-1 cause it was none till the firs condition check)
            A[i], A[j] = A[j], A[i] #-u swapping the position of the element < than pivot with 
                                    # i (index of green part), if it's already smaller thant it just update the
                                    # the index to match the < than part of array
                                    
    A[i+1], A[high] = A[high], A[i+1] # moving to the last part of the array the last bigger than the pivot number to get the array properly partitioned
    return i+1 #returning the index 

def quickSort_rec(A, low, high): # recursive implementation of the partition alorithm 
    if low < high: # checks if the lower index is less thant the higher one if true there are things to be sorted still
        pi = partition(A, low, high) 
        quickSort_rec(A, low, pi-1) # recursive call on one half
        quickSort_rec(A, pi+1, high) # recursive call on the other half till the array is sorted
        
def quickSort(A):
    B = A[:] # Copy the array just because we decided to return a sorted copy of the original array 
    quickSort_rec(B, low = 0, high = len(B)-1) 
    return B

# %% [markdown]
# ----
# ### Exercise: Merge Sort
# Complete the implementation of Merge Sort by implementing function ```merge()```.

# %%
## Your implementation here!!!

#------------------------------------------------------------# my implementation of the merge sort algorithm
def merge(A,l,m,r):
    
    B = [] # left it here because i wanted to make a copy that i didnt make for test purposes
    LA = A[l:m+1]
    RA = A[(m+1):(r+1)]
    
    i=j=0
    k = l
    
    while i < len(LA) and j < len(RA): 
        if LA[i] <= RA[j]: # if the left array at index i is smaller than the right array at index j it copies in the in the array a at index k
            A[k] = LA[i]
            i+=1 # if condition is true the index goes up by 1
        else: # if the right array at index j is smaller than the left array at index i it copies in the in the array a at index k 
            A[k] = RA[j] 
            j+=1 # if condition is true the index goes up by 1
        k += 1
    
    while i < len(LA): # copy and sort of the remaining elements in the left array, if one of the two is not completed sort the remaining elements
        A[k] = LA[i]
        i += 1
        k += 1

    while j < len(RA): # copy and sort of the remaining elements in the right array
        A[k] = RA[j]
        j += 1
        k += 1
#------------------------------------------------------------# 
        
        

def mergeSort_rec(A, l, r): 
    if l < r:       
        m = (l+(r-1))//2  # Same as (l+r)//2, but avoids overflow for large l and h 
        # Sort first and second halves 
        mergeSort_rec(A, l, m) 
        mergeSort_rec(A, m+1, r) 
        merge(A, l, m, r)
        
def mergeSort(B):
    A = B[:] # Copy the array just because we decided to return a sorted copy of the original array 
    mergeSort_rec(A, 0, len(A)-1) # 
    return A

# %% [markdown]
# ----
# # Lecture 3
# ----
# ### Exercise: Activity Selection Problem
# Activity selection problem is a problem in which a person has a list of works to do.
#
# Each of the activities has a starting time and ending time.
#
# We need to schedule the activities in such a way the person can complete a maximum number of activities.
#
# Since the timing of the activities  may overlap, so it might not be possible to complete all the activities and thus we need to schedule the activities in such a way that the maximum number of activities can be finished.

# %%
## your implementation here!!!

def best_activities_selection(A):
    
    sorted_activities = sorted(A, key = lambda x: x[1]) # sorting the activities by finish time (second element of the tuple)
    best_selection = []
    finish_time = sorted_activities[0][1] # setting the finish time to the first element of the sorted list
    best_selection.append(sorted_activities[0]) # appending the first activity to the best selection list
    
    for start, finish in sorted_activities: 
        activity = (start,finish) 
        
        if start >= finish_time: # checking if the start time of the activity is greater than the finish time of the previous activity
            best_selection.append(activity) # if true append the activity to the best selection list
            finish_time = finish # update the finish time to the finish time of the current activity
            
    return best_selection

# %% [markdown]
# ----
# ### Exercise: Fractional Knapsack Problem
#
# Your goal: Write a function fractional_knapsack(L,W) which takes a list L of pairs (value, weight) and the capacity  𝑊  and returns maximum possible value we can obtain by selecting items.

# %%
## Your implementation here!!!

import functools
def fractional_knapsack(L,W):
    
    def Knapsack_cmp(a,b): # function to compare the value/weight ratio of the items
        if a[0]/a[1] > b[0]/b[1]: return -1
        elif a[0]/a[1] < b[0]/b[1]: return 1
        else: return 0
        
    L_sorted = sorted(L, key=functools.cmp_to_key(Knapsack_cmp)) # sorting the list of items by value/weight ratio
    best_item_value = 0 

    for v,w in L_sorted: #if fits just put it inside the bag and update the weight
        if W - w >= 0:
            best_item_value += v
            W -= w
        else: # if it doesn't fit, take the fraction that fits and break the loop
            fittable_fraction = W/w
            best_item_value += fittable_fraction * v
            W = 0
            break
        
    return best_item_value

# %% [markdown]
# ----
# # Lecture 4 - lab06
#
# ----
#
# ### Exercise: K-largest elements of a array
#
# We want to compute the K-largest elements of a array A.
#
# There are three possible algorithms to solve this problem:
#
#
# #### Algorithm 1: Sorting
# The easiest way to solve this is by sorting the array in decreasing order and reporting the first K elements.
#
# This algorithm costs $\Theta(n\log n)$ time.
#
# Implement this algorithm in a function ```k_largest_sort(A, K)```and test its correctness.
#
# #### Algorithm 2: QuickSelect
# Implement the QuickSelect algorithm and use it to find the K-largest element E in the array A. Then, scan A again
# to collect the K elements larger than or equal to E. Finally, sort the collected elements.
#
# This algorithm costs $\Theta(n + K\log K)$ time (in expectation).
#
# Implement this algorithm in a function ```k_largest_quickselect(A, K)```and test its correctness.
#
#
# #### Algorithm 3: Heap
# You have to implement the following faster algorithm as a function ```k_largest(A,K)```.
# - Scan the array from left to right and keep a min-heap. The min-heap will contain at most K elements.
# - Insert the current element into the heap, if the heap has less than K elements or the current element is larger than the minimum in the heap. If the heap has more than K elements, remove the minimum.
# - Sort the collected elements.
#
# This algorithm runs in $\Theta(n\log K)$ time.
#
# Implement this algorithm in a function ```k_largest_heap(A, K)```and test its correctness.

# %%
### Algorithm 1 goes here

def k_largest_sort(A,K):
    A = sorted(A, reverse= True) # sorting the array in descending order
    return A[:K] # returning the first K elements of the array

# %%
### Algorithm 2 goes here

def partition(A, low, high): # partition algorithm from quicksort
    
    pivot = random.randint(low, high)
    A[pivot], A[high] = A[high], A[pivot]
    i = low - 1
    pivot = A[high]
    for j in range(low, high):
        if A[j] >= pivot:  # set the comparison to >= to get the k-th largest element or <= to get the k-th smallest element 
            i += 1
            A[i], A[j] = A[j], A[i]
    A[i + 1], A[high] = A[high], A[i + 1]
    return i + 1

def Quickselect(A, low, high, k): # quickselect algorithm to find the k-th largest element in the array
    if low == high:
        return A[low]
    partition_index = partition(A, low, high)
    if partition_index > k: 
        return Quickselect(A, low, partition_index - 1, k) # if the partition index is greater than k, we need to look for the k-th largest element in the left part of the array
    if partition_index < k:
        return Quickselect(A, partition_index + 1, high, k) # if the partition index is less than k, we need to look for the k-th largest element in the right part of the array
    else:
        return A[partition_index] 
        
def k_largest_quickselect(A,K): 
    E = Quickselect(A, 0, len(A)-1, K)
    k_largest = [num for num in A if num >= E] # creating a list of all the elements greater than or equal to the k-th largest element
    k_largest = sorted(k_largest, reverse= True)[:K] # sorting the list in descending order and returning the first K elements
    return k_largest

# %%
### Algorithm 3 goes here

def k_largest_heap(A,K): # using a min heap to find the k largest elements in the array
    min_heap = []
    for elem in A:
        if len(min_heap) < K or elem > min_heap[0]: 
            heapq.heappush(min_heap, elem) 
        if len(min_heap) > K:
            heapq.heappop(min_heap)
    return min_heap

# %% [markdown]
# ---
#
# ### Exercise: compute distinct elements
# You are given a list A of elements and you want to obtain the list of distict elements in A.
#
# There are two possible algorithms to do this:
#
# - Use ```list(set(A))```
# - Sort A and then scan. Implement this as a function ```distinct(A)```
#
# Compare these two approaches by varying the size of the array and the number of distinct elements.

# %%
## Your implementation here!!!

def distinct(A):
    A = sorted(A)
    distinct_elements = [A[i] for i in range(len(A)) if i == 0 or A[i] != A[i-1]]
    return distinct_elements

# %% [markdown]
# ---
#
# ### Exercise: Pareto frontier of a set of points in 2-D space (aka Skyline problem)
# We are given a set $S$ of $n$ 2D points.
# A point $(x,y)$ dominates a point $(x',y')$ iff $𝑥'\leq 𝑥$ and $y'\leq 𝑦$.
# Our goal is to find the set $P$ of dominating points in $S$.
# This corresponds to find the Pareto frontier (or, equivalently, the skyline).
#
# The problem can be solved in $\Theta(n\log n)$ time.
#
# To find $P$ we need to sort points in $S$ by $x$ in descending order,
# and if $x$′𝑠 the same by $y$ in descending order. This takes $\Theta(n\log n)$ time.
# Then, we do the following.
#
# - Include first point in $P$ and remember this point as $𝑇$.
# - Iterates through the point (let $C$ current point):
# * if $C$ is dominated by $T$, then skip $C$ and go to next point;
# * Otherwise, include $C$ in $P$ and set $𝑇=𝐶$.
#
# This step can be performed in linear time.
#
# Implement the function ```pareto_frontier(S)```, which returns the pareto frontier $P$ of the points in $S$.

# %%
## Your implementation here!!!

def pareto_frontier(S):
    
    S = sorted(S, key = lambda x: (-x[0], -x[1])) # sorting the list of points by decreasing x and y coordinates 
    
    T = S[0] # setting the first point as the temporary point
    P = [T] # creating a list of points that will be the pareto frontier 
    
    for C in S: # checking if the y coordinate of the current point is greater than the y coordinate of the temporary point 
        if C[1] < P[-1][1]: # if true, the current point is added to the pareto frontier list
            continue
        if C[1] > P[-1][1]: # if false, the current point becomes the temporary point
            T = C
            P.append(T)
        
    P = sorted(P)
    return P

# %% [markdown]
# ----
# # Lecture 5 - lab04
# ----
#
# ### Exercise: Open Addressing with linear probing
# Complete the implementation below by implementing ```Lookup```and ```Delete```.

# %%
## Your implementation here!!!

class linear_probing_set:
    def __init__(self, size):
        
        self.T = [None]*size
        self.prime = 993319
        self.a = random.randint(2, self.prime-1)
        self.b = random.randint(2, self.prime-1)
        self.n_keys = 0
    
    def insert(self, key): # fix len(T) < self.n_keys if you want
        if self.lookup(key):
            return
        h = self.hash(key)
        while self.T[h] != None and self.T[h] != 'D':
            h += 1
            if h == len(self.T):
                h = 0
        self.T[h] = key
        self.n_keys += 1
    
    #---------------------------------------------------------
    # Return True if key is in the set, False otherwise
    def lookup(self, key): 
        h = self.hash(key) 
        
        while self.T[h] != None: # while the current position is not empty
            if self.T[h] == key: # if the key is found, return True
                return True
            h += 1 # otherwise, keep looking for the key
            if h == len(self.T): # if the end of the array is reached, go back to the beginning - linear probing (while self.T[h] != None)
                h = 0
            
        if self.T[h] == "D": # if the current position is marked as deleted
            return "deleted"

        return False
            
    def delete(self, key):
        if self.lookup(key): #if key is in the set look for the key and delete it
            h = self.hash(key)
            while self.T[h] != None: 
                if self.T[h] == key:
                    self.T[h] = "D"
                    self.n_keys -= 1
                    return
                h += 1
                if h == len(self.T):
                    h = 0
        return "key not present"
    #---------------------------------------------------------
    
    
    def hash(self, key):
        return ((self.a*key + self.b) % self.prime) % len(self.T)
    
    def len(self):
        return self.n_keys

# %% [markdown]
# ----
# ### Exercise: Hashing with Chains
# Complete the implementation below by implementing ```Lookup``` and ```Delete```.

# %%
## Your implementation here!!!

class chaining_set:
    def __init__(self, size):
        
        self.T = []
        for _ in range(size):
            self.T.append([])
        ## self.T = [ [] for _ in range(size)] ## list comprehension version just cleaner
        ## why not self.T = [ [] ] * size ? ## cause it would create a list of size n but will reference 
                                            ## always the same inner one creating collisions
        
        self.prime = 993319
        self.a = random.randint(2, self.prime-1)
        self.b = random.randint(2, self.prime-1)
        self.n_keys = 0
        
    def insert(self, key):
        if self.lookup(key):
            return
        
        h = self.hash(key)
        self.T[h].append( key )
        self.n_keys += 1
    
    #---------------------------------------------------------
    # return True if key is in the set, False otherwise
    def lookup(self, key):
        h = self.hash(key)
        chain = self.T[h]
        
        for chain_key in chain:
            if chain_key == key: 
                return True
        return False
     
    def delete(self, key):
        if self.lookup(key):
            h = self.hash(key)
            chain = self.T[h]
        
            for j, chain_key in enumerate(chain):
                if chain_key == key:
                    chain[j] = "D" #didnt use the indexes in the previous one just to show differenet methods, using an index is always better
                    self.n_keys -=1
            return

        return "key not pesent"
    #---------------------------------------------------------
    
            
    def hash(self, key):
        return ((self.a*key + self.b) % self.prime) % len(self.T)
    
    def len(self):
        return self.n_keys

# %% [markdown]
# ----
#
# ### Exercise: Dictionary
# Modify the previous code (i.e., Hashing with Chains) to implement a dictionary, i.e., store a value together with each key.
# You need to implement methods:
# - ```Insert(key, value)```: insert the key with its value. If the key was already present, change its value;
# - ```Delete(key)```: remove the key;
# - ```Lookup(key)```: return True if the key is present, False otherwise;
# - ```Value(key)```: return the value associated with the key. It returns None, if the key is not present.
#
# I suggest to store pairs (key, value) within the lists.

# %%
## Your implementation here!!!

class chaining_set:
    def __init__(self, size):
        
        self.T = []
        for _ in range(size):
            self.T.append(list())
        ## self.T = [ [] for _ in range(size)] ## list comprehension version just cleaner
        ## why not self.T = [ [] ] * size ? ## cause it would create a list of size n but will reference 
                                            ## always the same inner one creating collisions
        self.prime = 993319
        self.a = random.randint(2, self.prime-1)
        self.b = random.randint(2, self.prime-1)
        self.n_keys = 0
        
    #---------------------------------------------------------
    def insert(self, key, value): 
        if self.lookup(key): # if the key is already present, update the value associated with it
            h = self.hash(key)
            chain = self.T[h] 
            for j, (chain_key, chain_value) in enumerate(chain): 
                if chain_key == key:
                    chain[j] = (key, value)
                return
            
        h = self.hash(key)
        self.T[h].append((key, value)) # otherwise, append the key-value pair to the chain 
        self.n_keys += 1
    
    # return True if key is in the set, False otherwise
    def lookup(self, key):
        h = self.hash(key)
        chain = self.T[h]
        
        for chain_elem in (chain):
            if isinstance(chain_elem, tuple): # check for the element to be a tuple to ensure correctness of the unpacking
                chain_key, chain_value = chain_elem
                if chain_key == key: 
                    return True
            if chain_elem == key: # there is an error in the one sent to the professor - the if statement was inside the check tuple condition for the unpacking
                return True 
        return False
    
    def value(self, key): # return the value associated with the key if present
        h = self.hash(key)
        chain = self.T[h]
        
        for (chain_key, chain_value) in chain:
            if chain_key == key: 
                return chain_value
        return None
     
    def delete(self, key):
        if self.lookup(key):
            h = self.hash(key)
            chain = self.T[h]
        
            for j, chain_elem in enumerate(chain):
                if isinstance(chain_elem, tuple): # check for the element to be a tuple to ensure correctness of the unpacking
                    chain_key, chain_value = chain_elem
                    if chain_key == key:
                        chain[j] = "D"
                        self.n_keys -=1
                if chain_elem == key: #check for both the element and tuple, if something went wrong during the insert or if empty part of the list  ## same error as above - the if statement was inside the check tuple condition for the unpacking
                    chain[j] = "D"
                    self.n_keys -= 1
            return

        return "key not pesent"
    #---------------------------------------------------------
    
            
    def hash(self, key):
        return ((self.a*key + self.b) % self.prime) % len(self.T)
    
    def len(self):
        return self.n_keys
    
## test implementation for value correctness

def get_random_array(n, max_val):
    return random.sample(range(max_val), n)

n = 10000

a = get_random_array(n, n)
values = get_random_array(n, n)  # Generate an array of random values to insert along with the key

queries = get_random_array(n, n)

c_set = chaining_set(2 * n)
std_set = set()
key_values = {} # create a dictonary to store the pairs of keys and values for further and more consistent checking

for i, key in enumerate(a):
    c_set.insert(key, values[i])  # Insert key along with the associated value in the value array
    std_set.add(key)
    key_values[key] = values[i] 

assert len(std_set) == c_set.len(), "Fail len!"

for i, key in enumerate(a):
    assert c_set.lookup(key) == True, "Lookup fail a"
    assert c_set.value(key) == key_values[key], "Value fail a" # check for the correctness of value

for key in queries:
    assert c_set.lookup(key) == (key in std_set), "Lookup fail queries"
    if key in std_set:
        assert c_set.value(key) == key_values[key], "Value fail queries" # check for the correctness of value

for i, key in enumerate(a[:300]):
    c_set.delete(key)
    try:
        std_set.remove(key)
    except:
        pass  # The key has already been removed
    
    assert c_set.lookup(key) == (key in std_set), "Lookup fail delete" ; 
    if key in std_set:
        assert c_set.value(key) == key_values[key], "Value fail delete" # check for the correctness of value

# %% [markdown]
# ---
# # Lecture 6 - lab05
#
# ---
# ### Exercise: Implements your own GroupBy
#
# In the rest of your life you are going to use GroupBy implemented in some library, but in this exercise we will implement our own simplified version.
#
# You are give a list of tuples, all with the same number of components. In our simplified implementation  of a pandas' DataFrame each tuple in the list is a row of the DataFrame. Each component of a tuple is a value of a column.
#
# #### Part I
# Our first goal is to implement an index to efficiently group by one of the component in the list.
#
# We'd like to implement a function ```groupBy(L, id)``` which takes the list of tuples ```L``` and the ```id``` of the component and returns a dictionary. The dictionary is an index very similar to what you implemented for a search engine.
# We have a key for each distinct value in column ```id```. The value of a certain key ```k``` is the list of indexes of all the tuple having value ```k``` in the column ```id```.
# This means that, if index ```p``` is in the list of key ```k```, then ```L[p][id] = k```.
#
# For example it we have tuples
#
# |   |
# |:-|
# (1, 5, 11)
# (0, 4, 1000)
# (1, 2, 11)
# (1, 4, 66)
# (0, 3, 99)
#
# The groupBy with id=0 will group by first column.
#
# The index is
#
# |   |
# |:--|
# 0: [1, 4]
# 1: [0, 2, 3]
#
# #### Part II
# We'd like to implement a function ```max_groupBy(index, L)``` which takes the index built in previous part on list ```L``` and returns a dictionary.
# We have a key for each distinct value in column ```id```. The value of a certain key ```k``` is the list. The list has a element for each column: the maximum value in that column for each tuple having value ```k``` in the column ```id```. This, of course, must be implemented by using the index.
#
# In the example before, we would obtain the dictionary
#
# |   |
# |:--|
# 0: [0, 4, 1000]
# 1: [1, 5, 66]

# %%
## Your implementation here!!!

## part I

def GroupBy(L,id): 
    dictonary = dict()
    
    for i, j in enumerate(L): 
        key = j[id]
        if key not in dictonary:
            dictonary[key] = []
        dictonary[key].append(i)
    return dictonary

## part II

def max_GroupBy(index, L): 
    dictonary = {}

    for key, rows in index.items():
        max_values = []
        for columns in range(len(L[0])): 
            column_values = [L[row][columns] for row in rows]
            max_values.append(max(column_values))
        dictonary[key] = [max_values]
    return dictonary

# %% [markdown]
# ---
# # Lecture 7
# ---
# ### Exercise: Static sorted map
# Complete and test the implementation below. You have to use binary search to solve predecessor and successor queries on a sorted array.

# %%
## Your implementation here!!!

class StaticSortedMap:
    def __init__(self, A): # assume A is already sorted
        self.sorted_map = A[:] # copy input array
        
    def min(self):
        return self.sorted_map[0]
    
    def max(self):
        return self.sorted_map[-1]
    
    
    #---------------------------------------------------------        
    def search(self, key): ## in our pseudocode BinarySearch(A, s, e, key)
        def __binary_search(p, e, key):
            if p <= e:
                mid = (p+e) // 2
                if self.sorted_map[mid] == key:
                    return (True, mid)
                
                elif self.sorted_map[mid] > key:
                    return __binary_search(p, mid-1, key)
                
                elif self.sorted_map[mid] < key:
                    return __binary_search(mid+1, e, key)
            
            else:
                if key < self.sorted_map[p]:
                    return (False, p)       #If the key is not in the set, returns False, p where p is the position where 
                                            # the key should be inserted to keep the array sorted.
                else:
                    return (False, p+1)
                     
        return __binary_search(0, len(self.sorted_map)-1, key)
        
    def predecessor(self, key):
        value, position = self.search(key)
        if value:
            if position == 0:
                return None
            else:
                return (position -1, self.sorted_map[position-1])
        else:
            return "key not found"
        
    def successor(self, key):
        value, position = self.search(key)
        if value:
            if position == len(self.sorted_map)-1:
                return None
            else:
                return (position +1, self.sorted_map[position+1])
        else:
            return "key not found"
    #---------------------------------------------------------

# %% [markdown]
# ----
# ### Exercise: Binary Search Tree
# Extend the previous implementation of Binary Search Trees to support **search(x)** operation. Test your implementation.

# %%
## Your implementation here!!!

class BinarySearchTree:
    # This is a Node class that is internal to the BinarySearchTree class
    class __Node:
        def __init__(self, val, left=None, right=None):
            self.val = val
            self.left = left
            self.right = right
            
        def getVal(self): 
            return self.val

        def setVal(self, newval): 
            self.val = newval
            
        def getLeft(self): 
            return self.left
        
        def getRight(self): 
            return self.right
        
        def setLeft(self, newleft): 
            self.left = newleft
        
        def setRight(self, newright): 
            self.right = newright
            
        # This method deserves a little explanation. It does an inorder traversal
        # of the nodes of the tree yielding all the values. In this way, we get
        # the values in ascending order.       
        def __iter__(self):
            if self.left != None:
                for elem in self.left: 
                    yield elem
            yield self.val
            if self.right != None:
                for elem in self.right:
                    yield elem
                    
    # Below methods of the BinarySearchTree class.
    def __init__(self): 
        self.root = None
         
    def insert(self, val):   
        # The __insert function is recursive and is not a passed a self parameter. It is a # static function (not a method of the class) but is hidden inside the insert
        # function so users of the class will not know it exists.
        def __insert(root, val): 
            if root == None:
                return BinarySearchTree.__Node(val)
            if val < root.getVal(): 
                root.setLeft( __insert(root.getLeft(), val) )
            else: 
                root.setRight( __insert(root.getRight(), val) )
            return root
        
        self.root = __insert(self.root, val)
        
    #--------------------------------------------------------- 
    def search(self, x):
        def __search(node, x):     # recursively iterates over the tree to find the value x, it starts from the root and goes on  
            if x == node.getVal():
                return True
            if x > node.getVal():  #to the right if the x is greater than the node value
                return __search(node.getRight(), x)
            if x < node.getVal():  #and to the left if the x is smaller than the node value
                return __search(node.getLeft(), x)
            else:
                return False
        return __search(self.root, x)
    #---------------------------------------------------------

# %% [markdown]
# ---
# # Lecture 8
# ---
# ### Exercise: Strongly Connected Components
# The goal of this exercise is to implement the following algorithm to compute the strongly connected components of a directed graph $G$. [See here](https://www.hackerearth.com/practice/algorithms/graphs/strongly-connected-components/tutorial/).
#
# In a directed graph a component is strongly connected if there is a directed path from any vertex to every other vertex of the component. The problem asks to is to partition the graph into maximal strongly connected components.
#
# NetworkX provides a method to compute the strongly connected components of a graph [here](https://networkx.github.io/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.strongly_connected_components.html#networkx.algorithms.components.strongly_connected_components).
#
# Your goal is to implement the Kosaraju's Linear time algorithm to find Strongly Connected Component.
# The algorithm is described [here](https://www.hackerearth.com/practice/algorithms/graphs/strongly-connected-components/tutorial).
#
# It works in three steps.
#
# - Do a DFS on the original graph, keeping track of the DFS finish times of each node. This can be done with a stack, when some  finishes put the source vertex on the stack. This way node with highest finishing time will be on top of the stack.
# - Reverse the original graph, i.e., if there is an edge $(u,v)$ in the original graph, add the edge $(v,u)$ in the reversed one.
# -  Do DFS on the reversed graph, with the source vertex as the vertex on top of the stack. When DFS finishes, all nodes visited will form one Strongly Connected Component. If any more nodes remain unvisited, this means there are more Strongly Connected Component's, so pop vertices from top of the stack until a valid unvisited node is found. This will have the highest finishing time of all currently unvisited nodes.
#
# Take a look at [DFS traversal documentation](https://networkx.github.io/documentation/stable/reference/algorithms/traversal.html#module-networkx.algorithms.traversal.depth_first_search).
# Note that the finishing time of a node can be inferred from its position in the DFS tree.

# %%
## Your implementation here!!!

def kosaraju_scc(G):
    
    stack = list(nx.dfs_postorder_nodes(G)) # First DFS to find the order of nodes in the stack

    Gr = nx.reverse(G) # Reverse the graph

    visited = set() 
    scc = []

    while stack: # Second DFS to find SCCs 
        node = stack.pop()
        if node not in visited:
            component = list(nx.dfs_preorder_nodes(Gr, node))
            visited.update(component) 
            scc.append(component)

    return scc

# right one kinda 
#---------------------------------------------------------
def kosaraju_scc(G):
    stack = []
    visited = set()
    scc = []
    
    for node in G:
        if node not in visited:
            DFS(G, node, visited, stack) # First DFS to find the order of nodes in the stack 

    Gr = nx.reverse(G, copy=True) # Reverse the graph
    
    visited = set()
    
    # Second DFS to find SCCs
    while stack:
        node = stack.pop()
        if node in visited:
            continue    
        if node not in visited:
            component = []
            DFS(Gr, node, visited, component)
            scc.append(set(component))

    return scc

def DFS(G, node, visited, component):
    visited.add(node)
    for n_node in G[node]:
        if n_node not in visited:
            DFS(G, n_node, visited, component)
    component.append(node)
